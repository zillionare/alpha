# %% [markdown]
# # 放量涨停
#
# 1. n日内有且仅有一个涨停，日线放量6倍以上。
# 2. 日线放量是过去至少20天内均值的5倍以上。
# 3. 过去存在一次放量（主力开始收集筹码）
# 4. 股价为60日内低位 wr < 0.6
#
# <img src="https://images.jieyu.ai/images/202111/20211103225820.png" width="450"/>

# %%
from alpha.notebook import *
from alpha.core.rsi_stats import rsi30, rsiday
from alpha.utils import math_round, buy_limit_price
from numpy.lib.stride_tricks import sliding_window_view

await init_notebook()
init_jq()

# %%
def scan_buy_limit(n = 20, adv_thres=0.8, secs=None):
    fields = ["open", "close", "high", "low", "volume", "high_limit"]
    
    secs = secs or Securities().choose(['stock'])
    
    rec_limit_per_req = 3000
    secs_per_req = rec_limit_per_req // n
    
    batches = len(secs) // secs_per_req + 1
    
    r1 = []
    for i in range(batches):
        codes = secs[i*secs_per_req:(i+1)*secs_per_req]
        bars = jq.get_price(codes, count=n, end_date=arrow.now().date(), fields=fields, panel=False,skip_paused=True)

        for code in codes:
            bar = bars[bars.code == code]
            
            close = bar['close'].values
            high_limit = bar['high_limit'].values
            volume = bar['volume'].values
            
            reach_buy_limit = np.abs(close - high_limit) < 1e-3
            total = np.count_nonzero(reach_buy_limit)
            last_5_days = np.count_nonzero(reach_buy_limit[-5:])
                        
            # 跳过当天涨停、最近5天涨停超过1次
            if not reach_buy_limit[-1] and total >= 1 and last_5_days <= 1:
                # 最后涨停时的坐标
                pos = np.argwhere(reach_buy_limit).flatten()[-1]
                mn = np.mean(volume[pos-5:pos])
                if mn > 0:
                    lb = volume[pos] / mn
                    r1.append((code, round(lb,1)))
                
    if len(r1) == 0:
        return []
    
    # 去掉半年内大涨的个股
    nbars = 120
    secs_per_req = rec_limit_per_req // nbars
    batches = len(secs) // secs_per_req + 1

    r2 = []
    for i in range(batches):
        recs = r1[i*secs_per_req: (i+1) * secs_per_req]
        codes = [rec[0] for rec in recs]
        
        if len(codes) == 0:
            break
            
        bars = jq.get_price(codes, count=nbars, end_date=arrow.now().date(), panel=False)
        for code, lb in recs:
            bar = bars[bars.code == code]
            close = bar['close'].values
                
            low = np.min(close)
        
            #print(bars.index[pos_high], close[pos_high], low, close[pos_high]/low - 1)
        
            adv = close[-1]/low - 1
            if adv > adv_thres:
                continue

            r2.append((code, Security(code).display_name, adv, lb))
        
    return pd.DataFrame(r2, columns=['code', 'name', 'adv', 'lb'])

# %%
class BuyLimitStrategy:
    def __init__(self, n:int):
        self.stats = self.reach_buy_limit_stats(n)
        
    def reach_buy_limit_stats(self, n:int):
        fields = ["open", "close", "high", "low", "volume", "high_limit"]

        secs = Securities().choose(['stock'])

        rec_limit_per_req = 3000
        secs_per_req = rec_limit_per_req // n

        batches = len(secs) // secs_per_req + 1

        r1 = []
        for i in range(batches):
            codes = secs[i*secs_per_req:(i+1)*secs_per_req]
            bars = jq.get_price(codes, count=n, end_date=arrow.now().date(), fields=fields, panel=False,skip_paused=True)

            for code in codes:
                bar = bars[bars.code == code]

                close = bar['close'].values
                high_limit = bar['high_limit'].values
                volume = bar['volume'].values

                reach_buy_limit = np.abs(close - high_limit) < 1e-3
                total = np.count_nonzero(reach_buy_limit)
                if total != 0:
                    r1.append((code, total, reach_buy_limit))

        return r1

    def filter_buy_limit(self, last_m:int, nzt:List, include_last = False):
        results = []
        for code, total, stats in self.stats:
            name = Security(code).display_name
            count = np.count_nonzero(stats[-last_m:])
            if count >= nzt[0] and count <= nzt[1] and not stats[-1]:
                results.append((name, code, total, count))
                
        return pd.DataFrame(results, columns = ["name", "code", "total", "recent"])

# %%
s = BuyLimitStrategy(120)
s.filter_buy_limit(5,[1,1])
# Out:
#      name         code  total  recent
# 0    神州数码  000034.XSHE      2       1
# 1    皇庭国际  000056.XSHE      8       1
# 2    常山北明  000158.XSHE      2       1
# 3    长航凤凰  000520.XSHE      4       1
# 4    神州信息  000555.XSHE      1       1
# ..    ...          ...    ...     ...
# 135  东亚药业  605177.XSHG      1       1
# 136  德才股份  605287.XSHG      2       1
# 137  晨光新材  605399.XSHG     11       1
# 138  东鹏饮料  605499.XSHG      2       1
# 139  圣泉集团  605589.XSHG      7       1
#
# [140 rows x 4 columns]

# %%
pd.options.display.max_rows=500
df[df.lb > 3].sort_values('lb', ascending=False)
# Out:
#             code  name       adv    lb
# 8    000419.XSHE  通程控股  0.193069  16.4
# 234  300939.XSHE   秋田微  0.345277  12.5
# 391  605060.XSHG  联德股份  0.317246  11.3
# 50   000955.XSHE  欣龙控股  0.287770  10.3
# 247  600118.XSHG  中国卫星  0.068715  10.0
# 381  603856.XSHG  东宏股份  0.466607   8.8
# 251  600168.XSHG  武汉控股  0.136876   8.7
# 372  603615.XSHG  茶花股份  0.151282   8.6
# 233  300933.XSHE  中辰股份  0.554382   8.2
# 330  601236.XSHG  红塔证券  0.049955   8.0
# 101  002217.XSHE   合力泰  0.261682   7.6
# 196  002963.XSHE   豪尔赛  0.239675   7.6
# 238  301043.XSHE   绿岛风       NaN   7.5
# 52   000970.XSHE  中科三环  0.368780   7.5
# 209  300149.XSHE  睿智医药  0.211838   7.4
# 81   002107.XSHE  沃华医药  0.291803   7.3
# 401  605188.XSHG  国光连锁  0.189076   7.0
# 227  300585.XSHE  奥联电子  0.488412   6.7
# 310  600790.XSHG   轻纺城  0.250000   6.5
# 189  002883.XSHE  中设股份  0.242678   6.3
# 368  603577.XSHG   汇金通  0.222360   6.2
# 76   002083.XSHE  孚日股份  0.239295   6.2
# 3    000158.XSHE  常山北明  0.200627   6.2
# 235  300942.XSHE  易瑞生物  0.451205   6.1
# 314  600833.XSHG  第一医药  0.182510   6.0
# 21   000619.XSHE  海螺型材  0.270613   5.8
# 346  603121.XSHG  华培动力  0.293305   5.7
# 84   002134.XSHE  天津普林  0.367008   5.6
# 53   000982.XSHE  中银绒业  0.504587   5.6
# 144  002589.XSHE  瑞康医药  0.296736   5.6
# 288  600477.XSHG  杭萧钢构  0.282799   5.4
# 351  603183.XSHG   建研院  0.264188   5.4
# 78   002094.XSHE  青岛金王  0.069409   5.3
# 147  002614.XSHE   奥佳华  0.186456   5.3
# 363  603390.XSHG  通达电气  0.233207   5.2
# 370  603602.XSHG  纵横通信  0.381776   5.1
# 392  605069.XSHG  正和生态       NaN   5.1
# 138  002556.XSHE  辉隆股份  0.366630   5.0
# 27   000705.XSHE  浙江震元  0.245283   4.9
# 332  601588.XSHG  北辰实业  0.314554   4.9
# 208  300111.XSHE   向日葵  0.348837   4.8
# 282  600423.XSHG  柳化股份  0.292683   4.8
# 151  002641.XSHE  永高股份  0.371495   4.8
# 40   000839.XSHE  中信国安  0.274882   4.8
# 303  600735.XSHG   新华锦  0.377395   4.8
# 71   002048.XSHE  宁波华翔  0.453002   4.8
# 134  002539.XSHE  云图控股  0.510160   4.7
# 406  605338.XSHG  巴比食品  0.382156   4.6
# 166  002735.XSHE  王子新材  0.568771   4.6
# 311  600815.XSHG  厦工股份  0.417778   4.5
# 240  301108.XSHE  洁雅股份       NaN   4.5
# 270  600337.XSHG  美克家居  0.223301   4.5
# 90   002172.XSHE  澳洋健康  0.237960   4.5
# 64   002001.XSHE   新和成  0.259836   4.3
# 213  300233.XSHE  金城医药  0.293423   4.3
# 2    000058.XSHE   深赛格  0.176580   4.3
# 369  603580.XSHG  艾艾精工  0.299471   4.3
# 226  300579.XSHE  数字认证  0.435603   4.3
# 350  603177.XSHG  德创环保  0.438277   4.2
# 298  600651.XSHG  飞乐音响  0.204947   4.2
# 286  600469.XSHG  风神股份  0.235589   4.2
# 164  002723.XSHE   金莱特  0.630040   4.2
# 228  300700.XSHE  岱勒新材  0.717172   4.2
# 373  603636.XSHG  南威软件  0.293082   4.2
# 224  300562.XSHE  乐心医疗  0.386111   4.2
# 41   000848.XSHE  承德露露  0.132829   4.2
# 163  002721.XSHE  金一文化  0.285185   4.1
# 212  300213.XSHE  佳讯飞鸿  0.430335   4.0
# 162  002715.XSHE  登云股份  0.280797   4.0
# 160  002705.XSHE  新宝股份  0.339471   4.0
# 23   000629.XSHE  攀钢钒钛  0.520755   4.0
# 124  002480.XSHE  新筑股份  0.512019   4.0
# 120  002368.XSHE  太极股份  0.372530   3.9
# 410  605589.XSHG  圣泉集团       NaN   3.8
# 10   000428.XSHE  华天酒店  0.333333   3.8
# 148  002627.XSHE  三峡旅游  0.098672   3.8
# 399  605177.XSHG  东亚药业  0.159363   3.8
# 376  603718.XSHG  海利生物  0.212121   3.8
# 313  600823.XSHG  世茂股份  0.159468   3.8
# 362  603387.XSHG  基蛋生物  0.235260   3.7
# 1    000032.XSHE  深桑达A  0.551578   3.7
# 210  300166.XSHE  东方国信  0.544393   3.7
# 200  003037.XSHE  三和管桩  0.261586   3.7
# 109  002303.XSHE   美盈森  0.199377   3.7
# 180  002816.XSHE   和科达  0.125711   3.7
# 400  605186.XSHG  健麾信息  0.391960   3.6
# 411  605598.XSHG  上海港湾       NaN   3.5
# 342  603077.XSHG  和邦生物  0.646018   3.5
# 58   001208.XSHE  华菱线缆  0.558190   3.5
# 230  300818.XSHE  耐普矿机  0.702713   3.5
# 67   002026.XSHE  山东威达  0.695958   3.5
# 402  605259.XSHG  绿田机械  0.270280   3.4
# 315  600843.XSHG  上工申贝  0.226619   3.3
# 383  603881.XSHG   数据港  0.379923   3.3
# 132  002516.XSHE  旷达科技  0.406316   3.3
# 389  603987.XSHG   康德莱  0.317816   3.3
# 412  605599.XSHG  菜百股份       NaN   3.3
# 312  600818.XSHG  中路股份  0.280303   3.3
# 301  600718.XSHG  东软集团  0.719260   3.3
# 141  002567.XSHE   唐人神  0.417254   3.2
# 396  605133.XSHG  嵘泰股份  0.719379   3.2
# 398  605167.XSHG   利柏特       NaN   3.2
# 220  300461.XSHE  田中精机  0.266282   3.2
# 354  603200.XSHG  上海洗霸  0.320000   3.2
# 279  600410.XSHG  华胜天成  0.302326   3.2
# 46   000917.XSHE  电广传媒  0.250460   3.2
# 173  002777.XSHE  久远银海  0.580529   3.1
# 190  002892.XSHE   科力尔  0.149599   3.1
# 127  002484.XSHE  江海股份  0.461404   3.1
# 197  002976.XSHE  瑞玛工业  0.320463   3.1
# 264  600288.XSHG  大恒科技  0.463602   3.1
# 155  002657.XSHE  中科金财  0.327801   3.1

# %% [markdown]
# # 板后三连阳

# %%
jq.get_current_tick("000001.XSHE")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/b5/73vzvtdn4pn_8wt6rpd2tb_w0000gn/T/ipykernel_59187/4047633479.py in <module>
# ----> 1 jq.get_current_tick("000001.XSHE")
#
# ~/miniforge3/envs/alpha/lib/python3.9/site-packages/jqdatasdk/api.py in get_current_tick(security)
#     592                 raise Exception(content)
#     593         else:
# --> 594             raise Exception(content)
#     595
#     596     stock_tick_fields = ['datetime', 'current', 'high', 'low', 'volume', 'money',
#
# Exception: error: 没有stocktick权限
# stocktick属于付费模块（仅限机构使用），如果您有购买需求，可添加微信号JQData02申请试用或咨询开通

# %%
jq.auth("18694978299", "87Ai2y3LzPOe")
# Out:
# auth success

# %%
tm = "2019-01-01T09:31:00Z"
from datetime import datetime

# %timeit datetime.strptime(tm, "%Y-%m-%dT%H:%M:%SZ")
# Out:
# 3.95 µs ± 20 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit arrow.get(tm)
# Out:
# 28.4 µs ± 189 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import numpy as np
# %timeit np.datetime64(tm).astype(datetime)
# Out:
# <magic-timeit>:1: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
# 1.09 µs ± 1.69 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
import ciso8601
# %timeit ciso8601.parse_datetime_as_naive(tm)
# Out:
# 90.9 ns ± 1.51 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)
